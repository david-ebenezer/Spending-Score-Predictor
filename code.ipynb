# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
customers=pd.read_csv("/content/Customers.csv - Customers.csv.csv")

# %%
customers.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
customers.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
customers.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]>

# %%
customers.hist(figsize=(16,16),bins=10)
plt.show()

# %%
customers.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
x=customers[['Age']]
y=customers[['Spending Score (1-100)']]

# %%
from sklearn.linear_model import LinearRegression
custModel= LinearRegression()
custModel.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=custModel.predict(x)

# %%
sns.lmplot(x='Age',y='Spending Score (1-100)',data=customers,aspect=2,height=6)

# %%
sample=custModel.predict([[60]])
sample=int(sample)
print("Spending Score " + str(sample))
# Out:
# Spending Score 37
